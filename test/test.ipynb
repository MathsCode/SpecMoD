# %%
import pickle
file_path = '/home/xujiaming/xujiaming/Paper/NIPS_SpecMoD/result/layer_data/question_0.pkl'
with open(file_path, 'rb') as file:
    loaded_list = pickle.load(file)

# %%
len(set())
# Out:
# 0

# %%
data.shape
# Out:
# torch.Size([64, 75846, 3])

# %%
_,indice = torch.topk(data[:,0,0],k=10)

# %%
[0] * 8
# Out:
# [0, 0, 0, 0, 0, 0, 0, 0]

# %%
import os
for root, dirs, files in os.walk('/home/xujiaming/xujiaming/Paper/NIPS_SpecMoD/result/layer_data'):
    for file in files:
        file_path = os.path.join(root, file)
        print(root)
# Out:
# /home/xujiaming/xujiaming/Paper/NIPS_SpecMoD/result/layer_data
# /home/xujiaming/xujiaming/Paper/NIPS_SpecMoD/result/layer_data
# /home/xujiaming/xujiaming/Paper/NIPS_SpecMoD/result/layer_data
# /home/xujiaming/xujiaming/Paper/NIPS_SpecMoD/result/layer_data
# /home/xujiaming/xujiaming/Paper/NIPS_SpecMoD/result/layer_data
# /home/xujiaming/xujiaming/Paper/NIPS_SpecMoD/result/layer_data

# %%
os.path.dirname('/home/xujiaming/xujiaming/Paper/NIPS_SpecMoD/result/layer_data/question_0.pkl')
# Out:
# '/home/xujiaming/xujiaming/Paper/NIPS_SpecMoD/result/layer_data'
