# %%
import pickle
file_path = '/home/xujiaming/xujiaming/Paper/NIPS_SpecMoD/result/cal_sim/sim_data.pkl'
with open(file_path, 'rb') as file:
    loaded_list = pickle.load(file)

# %%
import torch
data =torch.tensor(loaded_list)

# %%
data.shape
# Out:
# torch.Size([64, 75846, 3])

# %%
_,indice = torch.topk(data[:,0,0],k=10)

# %%
indice
# Out:
# tensor([42, 11, 43, 41, 40, 16,  2, 17, 12, 14])
